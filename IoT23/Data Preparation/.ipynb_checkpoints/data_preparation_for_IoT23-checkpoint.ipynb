# %% [markdown]
# # Preparing IoT23 dataset for Model training

# %%
import os
import numpy as np
import pandas as pd
import csv
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Data

# %%
capture_34 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-34-1/bro/conn.log.labeled"
capture_43 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-43-1/bro/conn.log.labeled"
capture_44 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-44-1/bro/conn.log.labeled"
capture_49 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-49-1/bro/conn.log.labeled"
capture_52 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-52-1/bro/conn.log.labeled"
capture_20 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-20-1/bro/conn.log.labeled"
capture_21 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-21-1/bro/conn.log.labeled"
capture_42 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-42-1/bro/conn.log.labeled"
capture_60 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-60-1/bro/conn.log.labeled"
capture_17 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-17-1/bro/conn.log.labeled"
capture_36 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-36-1/bro/conn.log.labeled"
capture_33 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-33-1/bro/conn.log.labeled"
capture_8 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-8-1/bro/conn.log.labeled"
capture_35 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-35-1/bro/conn.log.labeled"
capture_48 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-48-1/bro/conn.log.labeled"
capture_39 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-39-1/bro/conn.log.labeled"
capture_7 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-7-1/bro/conn.log.labeled"
capture_9 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-9-1/bro/conn.log.labeled"
capture_3 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-3-1/bro/conn.log.labeled"
capture_1 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-1-1/bro/conn.log.labeled"

# %%
df34 = pd.read_table(filepath_or_buffer=capture_34, skiprows=10, nrows=500000)
df34.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
                'label']
df34.drop(df34.tail(1).index,inplace=True)

# %%
df34.head()
# Out:
#                   ts                 uid      id.orig_h  id.orig_p  \
# 0  1545403848.981338   CDrkrSobGYxHhYfth  192.168.1.195    41040.0
# 1  1545403850.554283  CTWZQf2oJSvq6zmPAc  192.168.1.195    41042.0
# 2  1545403857.781320  CvyynC4Sabj9BNXFRi  192.168.1.195    41042.0
# 3  1545403859.183341  CWYyiA2sgRijwk2jEd  192.168.1.195    41044.0
# 4  1545403860.282392  CYttPy2pqOIcen7UDh  192.168.1.195    41046.0
#
#         id.resp_h  id.resp_p proto service  duration orig_bytes  ...  \
# 0  185.244.25.235       80.0   tcp    http  1.477656        149  ...
# 1  185.244.25.235       80.0   tcp       -  3.147116          0  ...
# 2  185.244.25.235       80.0   tcp    http  1.305004        151  ...
# 3  185.244.25.235       80.0   tcp    http  1.004605        148  ...
# 4  185.244.25.235       80.0   tcp    http  4.129647        148  ...
#
#   conn_state local_orig local_resp missed_bytes      history orig_pkts  \
# 0         SF          -          -       2896.0  ShADadttcfF      94.0
# 1         S0          -          -          0.0            S       3.0
# 2         SF          -          -       5792.0  ShADadttcfF      96.0
# 3         SF          -          -       2896.0   ShADadtcfF      67.0
# 4         SF          -          -       5792.0   ShADadtcfF      75.0
#
#    orig_ip_bytes  resp_pkts  resp_ip_bytes           label
# 0         5525.0       96.0       139044.0  -   Benign   -
# 1          180.0        0.0            0.0  -   Benign   -
# 2         5699.0       92.0       133140.0  -   Benign   -
# 3         4148.0       65.0        92453.0  -   Benign   -
# 4         4412.0       69.0        97107.0  -   Benign   -
#
# [5 rows x 21 columns]

# %%
df43 = pd.read_table(filepath_or_buffer=capture_43, skiprows=10, nrows=100000)
df43.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df43.drop(df43.tail(1).index,inplace=True)

# %%
df43.head()
# Out:
#              ts                 uid      id.orig_h  id.orig_p      id.resp_h  \
# 0  1.547145e+09  CqLUuz4jfs8yLCDXuj  192.168.1.198      36934  142.11.219.83
# 1  1.547145e+09  CnX96o42j3BWQZxqXj  192.168.1.198      36934  142.11.219.83
# 2  1.547145e+09   CKs4cs39inGUJYmcf  192.168.1.198      36934  142.11.219.83
# 3  1.547145e+09  CPeUF229WY3XhwerOl  192.168.1.198      36936  142.11.219.83
# 4  1.547145e+09   CJ5m8LQCMwvJDPuL5  192.168.1.198      36938  142.11.219.83
#
#    id.resp_p proto service  duration orig_bytes  ... conn_state local_orig  \
# 0         80   tcp       -         -          -  ...         S0          -
# 1         80   tcp       -         -          -  ...         S0          -
# 2         80   tcp    http  0.761313        157  ...         SF          -
# 3         80   tcp    http  0.783553         90  ...         SF          -
# 4         80   tcp       -  3.138207          0  ...         S0          -
#
#   local_resp missed_bytes    history orig_pkts  orig_ip_bytes  resp_pkts  \
# 0          -            0          S         1             60          0
# 1          -            0          S         1             60          0
# 2          -         4344  ShADadtfF        41           2381         40
# 3          -        10136  ShADadtfF        41           2302         40
# 4          -            0          S         3            180          0
#
#    resp_ip_bytes                             label
# 0              0               -   Malicious   C&C
# 1              0               -   Malicious   C&C
# 2          56393  -   Malicious   C&C-FileDownload
# 3          56393  -   Malicious   C&C-FileDownload
# 4              0               -   Malicious   C&C
#
# [5 rows x 21 columns]

# %%
df43.shape
# Out:
# (99999, 21)

# %%
df44 = pd.read_table(filepath_or_buffer=capture_44, skiprows=10, nrows=100000)
df44.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df44.drop(df44.tail(1).index,inplace=True)

# %%
df49 = pd.read_table(filepath_or_buffer=capture_49, skiprows=10, nrows=100000)
df49.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df49.drop(df49.tail(1).index,inplace=True)

# %%
df52 = pd.read_table(filepath_or_buffer=capture_52, skiprows=10, nrows=100000)
df52.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df52.drop(df52.tail(1).index,inplace=True)

# %%
df20 = pd.read_table(filepath_or_buffer=capture_20, skiprows=10, nrows=100000)
df20.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df20.drop(df20.tail(1).index,inplace=True)

# %%
df21 = pd.read_table(filepath_or_buffer=capture_21, skiprows=10, nrows=100000)
df21.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df21.drop(df21.tail(1).index,inplace=True)

# %%
df42 = pd.read_table(filepath_or_buffer=capture_42, skiprows=10, nrows=100000)
df42.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df42.drop(df42.tail(1).index,inplace=True)

# %%
df60 = pd.read_table(filepath_or_buffer=capture_60, skiprows=10, nrows=100000)
df60.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df60.drop(df60.tail(1).index,inplace=True)

# %%
df17 = pd.read_table(filepath_or_buffer=capture_17, skiprows=10, nrows=100000)
df17.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df17.drop(df17.tail(1).index,inplace=True)

# %%
df36 = pd.read_table(filepath_or_buffer=capture_36, skiprows=10, nrows=100000)
df36.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df36.drop(df36.tail(1).index,inplace=True)

# %%
df33 = pd.read_table(filepath_or_buffer=capture_33, skiprows=10, nrows=100000)
df33.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df33.drop(df33.tail(1).index,inplace=True)

# %%
df8 = pd.read_table(filepath_or_buffer=capture_8, skiprows=10, nrows=100000)
df8.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df8.drop(df8.tail(1).index,inplace=True)

# %%
df35 = pd.read_table(filepath_or_buffer=capture_35, skiprows=10, nrows=100000)
df35.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df35.drop(df35.tail(1).index,inplace=True)

# %%
df48 = pd.read_table(filepath_or_buffer=capture_48, skiprows=10, nrows=100000)
df48.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df48.drop(df48.tail(1).index,inplace=True)

# %%
df48
# Out:
#                  ts                 uid      id.orig_h  id.orig_p  \
# 0      1.551378e+09   CJMu2W757U3nVjHBg  192.168.1.200      52730
# 1      1.551378e+09  Csezqd4dveYyBuJOza  192.168.1.200      52732
# 2      1.551378e+09  CeGuVh3VK2bqRWuQEc  192.168.1.200      38448
# 3      1.551378e+09  ClyBYW2sZ2r420lBS1  192.168.1.200      47056
# 4      1.551378e+09  C7yyhA1w4KWuesvCV9  192.168.1.200      40544
# ...             ...                 ...            ...        ...
# 99994  1.551379e+09   CocDoG2EJXpNof2L5  192.168.1.200      42204
# 99995  1.551379e+09  CgFmZM2xLNReS4xbbk  192.168.1.200      42010
# 99996  1.551379e+09  CGb4Yf4a8mQolKQ78b  192.168.1.200      46266
# 99997  1.551379e+09   CRiVggDkeEWmMXEu2  192.168.1.200      52952
# 99998  1.551379e+09   Ct8uUyOan0RGW0RH6  192.168.1.200      44528
#
#              id.resp_h  id.resp_p proto service  duration  orig_bytes  ...  \
# 0       167.99.182.238         80   tcp    http  1.798966         149  ...
# 1       167.99.182.238         80   tcp    http  1.938142         149  ...
# 2              1.1.1.1         23   tcp       -  3.141713           0  ...
# 3              2.2.2.2         23   tcp       -  3.141708           0  ...
# 4              3.3.3.3         23   tcp       -  3.141709           0  ...
# ...                ...        ...   ...     ...       ...         ...  ...
# 99994  137.130.172.219         23   tcp       -  3.091489           0  ...
# 99995  138.131.173.220         23   tcp       -  3.119718           0  ...
# 99996  139.132.174.221         23   tcp       -  3.119712           0  ...
# 99997  140.133.175.222         23   tcp       -  3.119950           0  ...
# 99998  141.134.176.223         23   tcp       -  3.119729           0  ...
#
#        conn_state local_orig local_resp missed_bytes     history orig_pkts  \
# 0              SF          -          -            0  ShADadttfF       136
# 1              SF          -          -            0  ShADadttfF       170
# 2              S0          -          -            0           S         6
# 3              S0          -          -            0           S         6
# 4              S0          -          -            0           S         6
# ...           ...        ...        ...          ...         ...       ...
# 99994          S0          -          -            0           S         6
# 99995          S0          -          -            0           S         6
# 99996          S0          -          -            0           S         6
# 99997          S0          -          -            0           S         6
# 99998          S0          -          -            0           S         6
#
#        orig_ip_bytes  resp_pkts  resp_ip_bytes  \
# 0               8578        134         193266
# 1              11602        170         244256
# 2                360          0              0
# 3                360          0              0
# 4                360          0              0
# ...              ...        ...            ...
# 99994            360          0              0
# 99995            360          0              0
# 99996            360          0              0
# 99997            360          0              0
# 99998            360          0              0
#
#                                             label
# 0      -   Malicious   C&C-HeartBeat-FileDownload
# 1      -   Malicious   C&C-HeartBeat-FileDownload
# 2       -   Malicious   PartOfAHorizontalPortScan
# 3       -   Malicious   PartOfAHorizontalPortScan
# 4       -   Malicious   PartOfAHorizontalPortScan
# ...                                           ...
# 99994   -   Malicious   PartOfAHorizontalPortScan
# 99995   -   Malicious   PartOfAHorizontalPortScan
# 99996   -   Malicious   PartOfAHorizontalPortScan
# 99997   -   Malicious   PartOfAHorizontalPortScan
# 99998   -   Malicious   PartOfAHorizontalPortScan
#
# [99999 rows x 21 columns]

# %%
df39 = pd.read_table(filepath_or_buffer=capture_39, skiprows=10, nrows=100000)
df39.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df39.drop(df39.tail(1).index,inplace=True)

# %%
df7 = pd.read_table(filepath_or_buffer=capture_7, skiprows=10, nrows=100000)
df7.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df7.drop(df7.tail(1).index,inplace=True)

# %%
df9 = pd.read_table(filepath_or_buffer=capture_9, skiprows=10, nrows=100000)
df9.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df9.drop(df9.tail(1).index,inplace=True)

# %%
df3 = pd.read_table(filepath_or_buffer=capture_3, skiprows=10, nrows=100000)
df3.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
             'tunnel_parents',
              'label']
df3.drop(df3.tail(1).index,inplace=True)

# %%
df3
# Out:
#                ts                 uid    id.orig_h  id.orig_p  \
# 0      1526756317   C7NAoZ1GBUXpxV0sX  192.168.2.5      38797
# 1      1526756324   C8zmT04Y5NIOLxp0y  192.168.2.5      38797
# 2      1526756328   Ch70sn1L7zuOI4Qnc  192.168.2.5      38798
# 3      1526756278  CuOSYz3QNAKPuLEOXg  192.168.2.5        123
# 4      1526756243   Cr32XW1idd6BFFTCq  192.168.2.5        123
# ...           ...                 ...          ...        ...
# 99994  1526838779   CUHXxAhB6caYDvXu9  192.168.2.5      55016
# 99995  1526838780  CzW2gY2WM9n98h1lsk  192.168.2.5      55893
# 99996  1526838780  CiE1K71xhivlqUqB0k  192.168.2.5      49962
# 99997  1526838781  CYtBo83QdFi2JbDe7f  192.168.2.5      39905
# 99998  1526838781  CofJE115s4aa1C3Ie1  192.168.2.5      35780
#
#              id.resp_h  id.resp_p proto service   duration orig_bytes  ...  \
# 0       200.168.87.203      59353   tcp       -   2.998315          0  ...
# 1       200.168.87.203      59353   tcp       -          -          -  ...
# 2       200.168.87.203      59353   tcp       -   2.999395          0  ...
# 3       78.108.102.237        123   udp       -   0.012703         48  ...
# 4       37.157.198.150        123   udp       -  35.017664        288  ...
# ...                ...        ...   ...     ...        ...        ...  ...
# 99994   219.197.55.115         22   tcp       -    2.99477          0  ...
# 99995  219.167.202.241         22   tcp       -          -          -  ...
# 99996     219.36.89.23         22   tcp       -   2.993246          0  ...
# 99997    219.42.57.224         22   tcp       -          -          -  ...
# 99998     219.6.72.243         22   tcp       -    2.99095          0  ...
#
#       local_orig local_resp missed_bytes history  orig_pkts orig_ip_bytes  \
# 0              -          -            0       S          3           180
# 1              -          -            0       S          1            60
# 2              -          -            0       S          3           180
# 3              -          -            0      Dd          1            76
# 4              -          -            0      Dd          6           456
# ...          ...        ...          ...     ...        ...           ...
# 99994          -          -            0       S          3           180
# 99995          -          -            0       S          1            60
# 99996          -          -            0       S          3           180
# 99997          -          -            0       S          1            60
# 99998          -          -            0       S          3           180
#
#        resp_pkts  resp_ip_bytes  \
# 0              0              0
# 1              0              0
# 2              0              0
# 3              1             76
# 4              6            456
# ...          ...            ...
# 99994          0              0
# 99995          0              0
# 99996          0              0
# 99997          0              0
# 99998          0              0
#
#                                         tunnel_parents  label
# 0      (empty)   Malicious   PartOfAHorizontalPortScan    NaN
# 1      (empty)   Malicious   PartOfAHorizontalPortScan    NaN
# 2      (empty)   Malicious   PartOfAHorizontalPortScan    NaN
# 3                                 (empty)   Benign   -    NaN
# 4                                 (empty)   Benign   -    NaN
# ...                                                ...    ...
# 99994  (empty)   Malicious   PartOfAHorizontalPortScan    NaN
# 99995  (empty)   Malicious   PartOfAHorizontalPortScan    NaN
# 99996  (empty)   Malicious   PartOfAHorizontalPortScan    NaN
# 99997  (empty)   Malicious   PartOfAHorizontalPortScan    NaN
# 99998  (empty)   Malicious   PartOfAHorizontalPortScan    NaN
#
# [99999 rows x 22 columns]

# %%
df1 = pd.read_table(filepath_or_buffer=capture_1, skiprows=10, nrows=100000)
df1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
             'tunnel_parents',
              'label']
df1.drop(df1.tail(1).index,inplace=True)

# %%
frames=[df17, df20, df21, df33, df34, df35, df36, df39, df42, df43, df44, df48, df49, df52, df60, df7, df8, df9]

# %%
df_c=pd.concat(frames)

# %%
df_c.head()
# Out:
#             ts                 uid        id.orig_h  id.orig_p  \
# 0  1.53623e+09  CeqqKl3hyLQmO8LK98  192.168.100.111    17576.0
# 1  1.53623e+09   C2oHQWo1EFGH8D9x7  192.168.100.111    17576.0
# 2  1.53623e+09  CJLVjs4BByG04mczXc  192.168.100.111    17576.0
# 3  1.53623e+09   C0z4uS9AWHDH2s4S7  192.168.100.111    17576.0
# 4  1.53623e+09  CxbNVk3liFNUIlqSPi  192.168.100.111    17576.0
#
#         id.resp_h  id.resp_p proto service duration orig_bytes  ...  \
# 0    78.1.220.212     8081.0   tcp       -    3e-06          0  ...
# 1    152.84.7.111     8081.0   tcp       -    2e-06          0  ...
# 2    173.36.41.67     8081.0   tcp       -    2e-06          0  ...
# 3    87.13.21.104     8081.0   tcp       -    2e-06          0  ...
# 4  99.110.163.140     8081.0   tcp       -    2e-06          0  ...
#
#   conn_state local_orig local_resp missed_bytes  history orig_pkts  \
# 0         S0          -          -          0.0        S       2.0
# 1         S0          -          -          0.0        S       2.0
# 2         S0          -          -          0.0        S       2.0
# 3         S0          -          -          0.0        S       2.0
# 4         S0          -          -          0.0        S       2.0
#
#    orig_ip_bytes  resp_pkts  resp_ip_bytes  \
# 0           80.0        0.0            0.0
# 1           80.0        0.0            0.0
# 2           80.0        0.0            0.0
# 3           80.0        0.0            0.0
# 4           80.0        0.0            0.0
#
#                                        label
# 0  -   Malicious   PartOfAHorizontalPortScan
# 1  -   Malicious   PartOfAHorizontalPortScan
# 2  -   Malicious   PartOfAHorizontalPortScan
# 3  -   Malicious   PartOfAHorizontalPortScan
# 4  -   Malicious   PartOfAHorizontalPortScan
#
# [5 rows x 21 columns]

# %%
df_c.shape
# Out:
# (1244676, 21)

# %%
df_c['label'].value_counts()
# Out:
# -   Malicious   PartOfAHorizontalPortScan          578916
# -   Malicious   Okiru                              163016
# -   Benign   -                                     146275
# -   Malicious   DDoS                               138777
# (empty)   Malicious   Okiru                         99674
# (empty)   Malicious   PartOfAHorizontalPortScan     98911
# (empty)   Malicious   C&C                            8222
# -   Malicious   C&C                                  6871
# (empty)   Benign   -                                 3469
# -   Malicious   C&C-HeartBeat                         227
# (empty)   Malicious   C&C-HeartBeat                   122
# -   Malicious   Attack                                101
# -   Malicious   C&C-FileDownload                       43
# -   Malicious   C&C-Torii                              30
# -   Malicious   FileDownload                           13
# -   Malicious   C&C-HeartBeat-FileDownload              8
# -   Malicious   C&C-Mirai                               1
# Name: label, dtype: int64

# %%
df_c.loc[(df_c.label == '-   Malicious   PartOfAHorizontalPortScan'), 'label'] = 'POHS'
df_c.loc[(df_c.label == '(empty)   Malicious   PartOfAHorizontalPortScan'), 'label'] = 'POHS'
df_c.loc[(df_c.label == '-   Malicious   Okiru'), 'label'] = 'Okiru'
df_c.loc[(df_c.label == '(empty)   Malicious   Okiru'), 'label'] = 'Okiru'
df_c.loc[(df_c.label == '-   Benign   -'), 'label'] = 'Benign'
df_c.loc[(df_c.label == '(empty)   Benign   -'), 'label'] = 'Benign'
df_c.loc[(df_c.label == '-   Malicious   DDoS'), 'label'] = 'DDoS'
df_c.loc[(df_c.label == '-   Malicious   C&C'), 'label'] = 'C&C'
df_c.loc[(df_c.label == '(empty)   Malicious   C&C'), 'label'] = 'C&C'
df_c.loc[(df_c.label == '-   Malicious   Attack'), 'label'] = 'Attack'
df_c.loc[(df_c.label == '(empty)   Malicious   Attack'), 'label'] = 'Attack'
df_c.loc[(df_c.label == '-   Malicious   C&C-HeartBeat'), 'label'] = 'C&C-HeartBeat'
df_c.loc[(df_c.label == '(empty)   Malicious   C&C-HeartBeat'), 'label'] = 'C&C-HeartBeat'
df_c.loc[(df_c.label == '-   Malicious   C&C-FileDownload'), 'label'] = 'C&C-FileDownload'
df_c.loc[(df_c.label == '-   Malicious   C&C-Torii'), 'label'] = 'C&C-Torii'
df_c.loc[(df_c.label == '-   Malicious   C&C-HeartBeat-FileDownload'), 'label'] = 'C&C-HeartBeat-FileDownload'
df_c.loc[(df_c.label == '-   Malicious   FileDownload'), 'label'] = 'FileDownload'
df_c.loc[(df_c.label == '-   Malicious   C&C-Mirai'), 'label'] = 'C&C-Mirai'
df_c.loc[(df_c.label == '-   Malicious   Okiru-Attack'), 'label'] = 'Okiru-Attack'

# %%
df_c['label'].value_counts()
# Out:
# POHS                          677827
# Okiru                         262690
# Benign                        149744
# DDoS                          138777
# C&C                            15093
# C&C-HeartBeat                    349
# Attack                           101
# C&C-FileDownload                  43
# C&C-Torii                         30
# FileDownload                      13
# C&C-HeartBeat-FileDownload         8
# C&C-Mirai                          1
# Name: label, dtype: int64

# %%
pd.options.display.max_rows = 300
pd.options.display.max_columns = 300

# %%
df_c
# Out:
#                 ts                 uid        id.orig_h  id.orig_p  \
# 0      1.53623e+09  CeqqKl3hyLQmO8LK98  192.168.100.111    17576.0
# 1      1.53623e+09   C2oHQWo1EFGH8D9x7  192.168.100.111    17576.0
# 2      1.53623e+09  CJLVjs4BByG04mczXc  192.168.100.111    17576.0
# 3      1.53623e+09   C0z4uS9AWHDH2s4S7  192.168.100.111    17576.0
# 4      1.53623e+09  CxbNVk3liFNUIlqSPi  192.168.100.111    17576.0
# ...            ...                 ...              ...        ...
# 99994  1.53253e+09  CMeH6R2aua5c5Dd65a  192.168.100.111    41762.0
# 99995  1.53253e+09  CvqGx33hsXDpDVXa1i  192.168.100.111    58758.0
# 99996  1.53253e+09   CC83RoUd9RLFuTL81  192.168.100.111    40400.0
# 99997  1.53253e+09  C4ISld2cuSukEEuQtk  192.168.100.111    27117.0
# 99998  1.53253e+09   C4U1azYmDx32faVY7  192.168.100.111    23227.0
#
#              id.resp_h  id.resp_p proto service duration orig_bytes  \
# 0         78.1.220.212     8081.0   tcp       -    3e-06          0
# 1         152.84.7.111     8081.0   tcp       -    2e-06          0
# 2         173.36.41.67     8081.0   tcp       -    2e-06          0
# 3         87.13.21.104     8081.0   tcp       -    2e-06          0
# 4       99.110.163.140     8081.0   tcp       -    2e-06          0
# ...                ...        ...   ...     ...      ...        ...
# 99994  221.182.209.127       23.0   tcp       -        -          -
# 99995    208.50.139.48       23.0   tcp       -        -          -
# 99996     40.95.136.51       23.0   tcp       -        -          -
# 99997   122.37.183.236       23.0   tcp       -        -          -
# 99998   189.62.234.179       23.0   tcp       -        -          -
#
#       resp_bytes conn_state local_orig local_resp  missed_bytes history  \
# 0              0         S0          -          -           0.0       S
# 1              0         S0          -          -           0.0       S
# 2              0         S0          -          -           0.0       S
# 3              0         S0          -          -           0.0       S
# 4              0         S0          -          -           0.0       S
# ...          ...        ...        ...        ...           ...     ...
# 99994          -         S0          -          -           0.0       S
# 99995          -         S0          -          -           0.0       S
# 99996          -         S0          -          -           0.0       S
# 99997          -         S0          -          -           0.0       S
# 99998          -         S0          -          -           0.0       S
#
#        orig_pkts  orig_ip_bytes  resp_pkts  resp_ip_bytes label
# 0            2.0           80.0        0.0            0.0  POHS
# 1            2.0           80.0        0.0            0.0  POHS
# 2            2.0           80.0        0.0            0.0  POHS
# 3            2.0           80.0        0.0            0.0  POHS
# 4            2.0           80.0        0.0            0.0  POHS
# ...          ...            ...        ...            ...   ...
# 99994        1.0           40.0        0.0            0.0  POHS
# 99995        1.0           40.0        0.0            0.0  POHS
# 99996        1.0           40.0        0.0            0.0  POHS
# 99997        1.0           40.0        0.0            0.0  POHS
# 99998        1.0           40.0        0.0            0.0  POHS
#
# [1244676 rows x 21 columns]

# %%
df_c = df_c.drop(columns=['uid','id.orig_h','id.orig_p','id.resp_h','id.resp_p','local_orig','local_resp'])

# %%
df_c = pd.get_dummies(df_c, columns=['proto'])
df_c = pd.get_dummies(df_c, columns=['conn_state'])

# %%
df_c
# Out:
#                 ts                 uid        id.orig_h  id.orig_p  \
# 0      1.53623e+09  CeqqKl3hyLQmO8LK98  192.168.100.111    17576.0
# 1      1.53623e+09   C2oHQWo1EFGH8D9x7  192.168.100.111    17576.0
# 2      1.53623e+09  CJLVjs4BByG04mczXc  192.168.100.111    17576.0
# 3      1.53623e+09   C0z4uS9AWHDH2s4S7  192.168.100.111    17576.0
# 4      1.53623e+09  CxbNVk3liFNUIlqSPi  192.168.100.111    17576.0
# ...            ...                 ...              ...        ...
# 99994  1.53253e+09  CMeH6R2aua5c5Dd65a  192.168.100.111    41762.0
# 99995  1.53253e+09  CvqGx33hsXDpDVXa1i  192.168.100.111    58758.0
# 99996  1.53253e+09   CC83RoUd9RLFuTL81  192.168.100.111    40400.0
# 99997  1.53253e+09  C4ISld2cuSukEEuQtk  192.168.100.111    27117.0
# 99998  1.53253e+09   C4U1azYmDx32faVY7  192.168.100.111    23227.0
#
#              id.resp_h  id.resp_p proto service duration orig_bytes  \
# 0         78.1.220.212     8081.0   tcp       -    3e-06          0
# 1         152.84.7.111     8081.0   tcp       -    2e-06          0
# 2         173.36.41.67     8081.0   tcp       -    2e-06          0
# 3         87.13.21.104     8081.0   tcp       -    2e-06          0
# 4       99.110.163.140     8081.0   tcp       -    2e-06          0
# ...                ...        ...   ...     ...      ...        ...
# 99994  221.182.209.127       23.0   tcp       -        -          -
# 99995    208.50.139.48       23.0   tcp       -        -          -
# 99996     40.95.136.51       23.0   tcp       -        -          -
# 99997   122.37.183.236       23.0   tcp       -        -          -
# 99998   189.62.234.179       23.0   tcp       -        -          -
#
#       resp_bytes conn_state local_orig local_resp  missed_bytes history  \
# 0              0         S0          -          -           0.0       S
# 1              0         S0          -          -           0.0       S
# 2              0         S0          -          -           0.0       S
# 3              0         S0          -          -           0.0       S
# 4              0         S0          -          -           0.0       S
# ...          ...        ...        ...        ...           ...     ...
# 99994          -         S0          -          -           0.0       S
# 99995          -         S0          -          -           0.0       S
# 99996          -         S0          -          -           0.0       S
# 99997          -         S0          -          -           0.0       S
# 99998          -         S0          -          -           0.0       S
#
#        orig_pkts  orig_ip_bytes  resp_pkts  resp_ip_bytes label
# 0            2.0           80.0        0.0            0.0  POHS
# 1            2.0           80.0        0.0            0.0  POHS
# 2            2.0           80.0        0.0            0.0  POHS
# 3            2.0           80.0        0.0            0.0  POHS
# 4            2.0           80.0        0.0            0.0  POHS
# ...          ...            ...        ...            ...   ...
# 99994        1.0           40.0        0.0            0.0  POHS
# 99995        1.0           40.0        0.0            0.0  POHS
# 99996        1.0           40.0        0.0            0.0  POHS
# 99997        1.0           40.0        0.0            0.0  POHS
# 99998        1.0           40.0        0.0            0.0  POHS
#
# [1244676 rows x 21 columns]

# %%
df_c.to_csv('iot23_combined_1M.csv')

# %%
df_c.head()
# Out:
#             ts                 uid        id.orig_h  id.orig_p  \
# 0  1.53623e+09  CeqqKl3hyLQmO8LK98  192.168.100.111    17576.0
# 1  1.53623e+09   C2oHQWo1EFGH8D9x7  192.168.100.111    17576.0
# 2  1.53623e+09  CJLVjs4BByG04mczXc  192.168.100.111    17576.0
# 3  1.53623e+09   C0z4uS9AWHDH2s4S7  192.168.100.111    17576.0
# 4  1.53623e+09  CxbNVk3liFNUIlqSPi  192.168.100.111    17576.0
#
#         id.resp_h  id.resp_p proto service duration orig_bytes resp_bytes  \
# 0    78.1.220.212     8081.0   tcp       -    3e-06          0          0
# 1    152.84.7.111     8081.0   tcp       -    2e-06          0          0
# 2    173.36.41.67     8081.0   tcp       -    2e-06          0          0
# 3    87.13.21.104     8081.0   tcp       -    2e-06          0          0
# 4  99.110.163.140     8081.0   tcp       -    2e-06          0          0
#
#   conn_state local_orig local_resp  missed_bytes history  orig_pkts  \
# 0         S0          -          -           0.0       S        2.0
# 1         S0          -          -           0.0       S        2.0
# 2         S0          -          -           0.0       S        2.0
# 3         S0          -          -           0.0       S        2.0
# 4         S0          -          -           0.0       S        2.0
#
#    orig_ip_bytes  resp_pkts  resp_ip_bytes label
# 0           80.0        0.0            0.0  POHS
# 1           80.0        0.0            0.0  POHS
# 2           80.0        0.0            0.0  POHS
# 3           80.0        0.0            0.0  POHS
# 4           80.0        0.0            0.0  POHS

# %%
df_c['duration'] = df_c['duration'].str.replace('-','0')
df_c['orig_bytes'] = df_c['orig_bytes'].str.replace('-','0')
df_c['resp_bytes'] = df_c['resp_bytes'].str.replace('-','0')

# %%
df_c.fillna(-1,inplace=True)

# %%
df_c.isna().sum()
# Out:
# ts               0
# proto            0
# service          0
# duration         0
# orig_bytes       0
# resp_bytes       0
# conn_state       0
# missed_bytes     0
# history          0
# orig_pkts        0
# orig_ip_bytes    0
# resp_pkts        0
# resp_ip_bytes    0
# label            0
# dtype: int64

# %%
print(df_c.columns.tolist())
# Out:
# ['ts', 'proto', 'service', 'duration', 'orig_bytes', 'resp_bytes', 'conn_state', 'missed_bytes', 'history', 'orig_pkts', 'orig_ip_bytes', 'resp_pkts', 'resp_ip_bytes', 'label']

# %% [markdown]
# # CONVERTING TO CSV FILE FOR FUTURE USE

# %% [markdown]
# keep in mind that we missed 2 packet captures due to a mismatch problem in the columns. We will look into
# this problem again and try to resolve this.

# %%
df_c.to_csv('iot23_combined_updated_1M.csv')

# %%
df_c.head()
# Out:
#             ts proto service duration orig_bytes resp_bytes conn_state  \
# 0  1.53623e+09   tcp       -       -1         -1         -1         S0
# 1  1.53623e+09   tcp       -       -1         -1         -1         S0
# 2  1.53623e+09   tcp       -       -1         -1         -1         S0
# 3  1.53623e+09   tcp       -       -1         -1         -1         S0
# 4  1.53623e+09   tcp       -       -1         -1         -1         S0
#
#    missed_bytes history  orig_pkts  orig_ip_bytes  resp_pkts  resp_ip_bytes  \
# 0           0.0       S        2.0           80.0        0.0            0.0
# 1           0.0       S        2.0           80.0        0.0            0.0
# 2           0.0       S        2.0           80.0        0.0            0.0
# 3           0.0       S        2.0           80.0        0.0            0.0
# 4           0.0       S        2.0           80.0        0.0            0.0
#
#   label
# 0  POHS
# 1  POHS
# 2  POHS
# 3  POHS
# 4  POHS
