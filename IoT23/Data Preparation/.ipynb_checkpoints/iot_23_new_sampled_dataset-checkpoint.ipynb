# %%
import os
import numpy as np
import pandas as pd
import csv
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Import data

# %%
capture_34 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-34-1/bro/conn.log.labeled"

# %%
capture_36 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-36-1/bro/conn.log.labeled"

# %%
capture_3 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-3-1/bro/conn.log.labeled"

# %%
capture_1 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-1-1/bro/conn.log.labeled"

# %%
honeypot_1= "D:/Final Theses Project/Research Paper/Dataset/HoneyPot/CTU-Honeypot-Capture-4-1/bro/conn.log.labeled"
honeypot_2= "D:/Final Theses Project/Research Paper/Dataset/HoneyPot/CTU-Honeypot-Capture-5-1/bro/conn.log.labeled"
honeypot_3= "D:/Final Theses Project/Research Paper/Dataset/HoneyPot/CTU-Honeypot-Capture-7-1/Somfy-01/bro/conn.log.labeled"

# %%
========================================

# %%
capture_60 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-60-1/bro/conn.log.labeled"
capture_17 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-17-1/bro/conn.log.labeled"
capture_39 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-39-1/bro/conn.log.labeled"
capture_9 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-9-1/bro/conn.log.labeled"


capture_8 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-8-1/bro/conn.log.labeled"
capture_20 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-20-1/bro/conn.log.labeled"
capture_21 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-21-1/bro/conn.log.labeled"

# %%
honeypot_1= "D:/Final Theses Project/Research Paper/Dataset/HoneyPot/CTU-Honeypot-Capture-4-1/bro/conn.log.labeled"
honeypot_2= "D:/Final Theses Project/Research Paper/Dataset/HoneyPot/CTU-Honeypot-Capture-5-1/bro/conn.log.labeled"
honeypot_3= "D:/Final Theses Project/Research Paper/Dataset/HoneyPot/CTU-Honeypot-Capture-7-1/Somfy-01/bro/conn.log.labeled"

# %%
====================================================================================

# %% [markdown]
# Creating dataset from only 2 captures...34 and 36.. and all sample dataset

# %%
df1 = pd.read_table(filepath_or_buffer=capture_1, skiprows=10, nrows=100000)
df1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label',
             ' '
            ]
df1.drop(df1.tail(1).index,inplace=True)

# %%
df1.head()
# Out:
#            ts                 uid        id.orig_h  id.orig_p  \
# 0  1525879836  CgeVK21nm6PyVgJ4ah  192.168.100.103      40973
# 1  1525879837  CFXxTW19F3sluNEkJk  192.168.100.103      52259
# 2  1525879838  CRRl9U39PzvL3OiS61  192.168.100.103      42207
# 3  1525879838  C9hk4p2z9Y6AvlzLff  192.168.100.103      51524
# 4  1525879839  Cx7t1f1wqRES8kiTq6  192.168.100.103      40459
#
#          id.resp_h  id.resp_p proto service  duration orig_bytes  ...  \
# 0   62.239.193.205       8080   tcp       -         -          -  ...
# 1  193.189.106.178         23   tcp       -    2.9993          0  ...
# 2    10.169.219.98       8080   tcp       -  2.993548          0  ...
# 3   65.127.233.163         23   tcp       -         -          -  ...
# 4  212.110.180.188         23   tcp       -  2.998807          0  ...
#
#   local_orig local_resp missed_bytes history  orig_pkts orig_ip_bytes  \
# 0          -          -            0       S          1            60
# 1          -          -            0       S          3           180
# 2          -          -            0       S          3           180
# 3          -          -            0       S          1            60
# 4          -          -            0       S          3           180
#
#    resp_pkts  resp_ip_bytes                                            label  \
# 0          0              0  (empty)   Malicious   PartOfAHorizontalPortScan
# 1          0              0  (empty)   Malicious   PartOfAHorizontalPortScan
# 2          0              0  (empty)   Malicious   PartOfAHorizontalPortScan
# 3          0              0  (empty)   Malicious   PartOfAHorizontalPortScan
# 4          0              0  (empty)   Malicious   PartOfAHorizontalPortScan
#
#
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
#
# [5 rows x 22 columns]

# %%
df1.drop(columns=[' '], inplace=True)

# %%
df1.head()
# Out:
#            ts                 uid        id.orig_h  id.orig_p  \
# 0  1525879836  CgeVK21nm6PyVgJ4ah  192.168.100.103      40973
# 1  1525879837  CFXxTW19F3sluNEkJk  192.168.100.103      52259
# 2  1525879838  CRRl9U39PzvL3OiS61  192.168.100.103      42207
# 3  1525879838  C9hk4p2z9Y6AvlzLff  192.168.100.103      51524
# 4  1525879839  Cx7t1f1wqRES8kiTq6  192.168.100.103      40459
#
#          id.resp_h  id.resp_p proto service  duration orig_bytes  ...  \
# 0   62.239.193.205       8080   tcp       -         -          -  ...
# 1  193.189.106.178         23   tcp       -    2.9993          0  ...
# 2    10.169.219.98       8080   tcp       -  2.993548          0  ...
# 3   65.127.233.163         23   tcp       -         -          -  ...
# 4  212.110.180.188         23   tcp       -  2.998807          0  ...
#
#   conn_state local_orig local_resp missed_bytes  history orig_pkts  \
# 0         S0          -          -            0        S         1
# 1         S0          -          -            0        S         3
# 2         S0          -          -            0        S         3
# 3         S0          -          -            0        S         1
# 4         S0          -          -            0        S         3
#
#    orig_ip_bytes  resp_pkts  resp_ip_bytes  \
# 0             60          0              0
# 1            180          0              0
# 2            180          0              0
# 3             60          0              0
# 4            180          0              0
#
#                                              label
# 0  (empty)   Malicious   PartOfAHorizontalPortScan
# 1  (empty)   Malicious   PartOfAHorizontalPortScan
# 2  (empty)   Malicious   PartOfAHorizontalPortScan
# 3  (empty)   Malicious   PartOfAHorizontalPortScan
# 4  (empty)   Malicious   PartOfAHorizontalPortScan
#
# [5 rows x 21 columns]

# %%
df34 = pd.read_table(filepath_or_buffer=capture_34, skiprows=10, nrows=100000)

# %%
df34.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
                'label']
df34.drop(df34.tail(1).index,inplace=True)

# %%
df34
# Out:
#                       ts                 uid      id.orig_h  id.orig_p  \
# 0      1545403848.981338   CDrkrSobGYxHhYfth  192.168.1.195    41040.0
# 1      1545403850.554283  CTWZQf2oJSvq6zmPAc  192.168.1.195    41042.0
# 2      1545403857.781320  CvyynC4Sabj9BNXFRi  192.168.1.195    41042.0
# 3      1545403859.183341  CWYyiA2sgRijwk2jEd  192.168.1.195    41044.0
# 4      1545403860.282392  CYttPy2pqOIcen7UDh  192.168.1.195    41046.0
# ...                  ...                 ...            ...        ...
# 23137  1545490133.961380   C2F17zSUnGOcWzBa7  192.168.1.195    57110.0
# 23138  1545489934.221598  C93P4z4k5IRJD1rXJg  192.168.1.195    57092.0
# 23139  1545490198.463564  CXLZ3A2QY5E8weqpDk  192.168.1.195      123.0
# 23140  1545490181.542213  CuXpFN3fWesWBXUhq1  192.168.1.195      123.0
# 23141  1545490198.459568  Ct2Yhy4d33oL3yyZY9  192.168.1.195      123.0
#
#             id.resp_h  id.resp_p proto service   duration orig_bytes  ...  \
# 0      185.244.25.235       80.0   tcp    http   1.477656        149  ...
# 1      185.244.25.235       80.0   tcp       -   3.147116          0  ...
# 2      185.244.25.235       80.0   tcp    http   1.305004        151  ...
# 3      185.244.25.235       80.0   tcp    http   1.004605        148  ...
# 4      185.244.25.235       80.0   tcp    http   4.129647        148  ...
# ...               ...        ...   ...     ...        ...        ...  ...
# 23137  185.244.25.235     6667.0   tcp     irc  32.840994         62  ...
# 23138  185.244.25.235     6667.0   tcp     irc  36.290833         62  ...
# 23139  147.251.48.140      123.0   udp       -          -          -  ...
# 23140    82.113.53.40      123.0   udp       -          -          -  ...
# 23141  89.221.210.188      123.0   udp       -          -          -  ...
#
#       conn_state local_orig local_resp missed_bytes      history orig_pkts  \
# 0             SF          -          -       2896.0  ShADadttcfF      94.0
# 1             S0          -          -          0.0            S       3.0
# 2             SF          -          -       5792.0  ShADadttcfF      96.0
# 3             SF          -          -       2896.0   ShADadtcfF      67.0
# 4             SF          -          -       5792.0   ShADadtcfF      75.0
# ...          ...        ...        ...          ...          ...       ...
# 23137         S3          -          -          0.0      ShAdDaf       7.0
# 23138         S3          -          -          0.0      ShAdDaf      10.0
# 23139         S0          -          -          0.0            D       1.0
# 23140         S0          -          -          0.0            D       1.0
# 23141         S0          -          -          0.0            D       1.0
#
#        orig_ip_bytes  resp_pkts  resp_ip_bytes                label
# 0             5525.0       96.0       139044.0       -   Benign   -
# 1              180.0        0.0            0.0       -   Benign   -
# 2             5699.0       92.0       133140.0       -   Benign   -
# 3             4148.0       65.0        92453.0       -   Benign   -
# 4             4412.0       69.0        97107.0       -   Benign   -
# ...              ...        ...            ...                  ...
# 23137          434.0        6.0          589.0  -   Malicious   C&C
# 23138          606.0        7.0          632.0  -   Malicious   C&C
# 23139           76.0        0.0            0.0       -   Benign   -
# 23140           76.0        0.0            0.0       -   Benign   -
# 23141           76.0        0.0            0.0       -   Benign   -
#
# [23142 rows x 21 columns]

# %%
df36 = pd.read_table(filepath_or_buffer=capture_36, skiprows=10, nrows=100000)
df36.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'tunnel_parents',
               'label']
df36.drop(df36.tail(1).index,inplace=True)

# %% [markdown]
# # Benign Data Scenarios

# %%
df_h1 = pd.read_table(filepath_or_buffer=honeypot_1, skiprows=10)
df_h1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df_h1.drop(df_h1.tail(1).index,inplace=True)

# %%
df_h2 = pd.read_table(filepath_or_buffer=honeypot_2, skiprows=10)
df_h2.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df_h2.drop(df_h2.tail(1).index,inplace=True)

# %%
df_h3 = pd.read_table(filepath_or_buffer=honeypot_3, skiprows=10, nrows=100000)
df_h3.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df_h3.drop(df_h3.tail(1).index,inplace=True)

# %% [markdown]
# # Joining all the dataframes

# %%
frames=[df1,df34, df36, df_h1, df_h2, df_h3]

# %%
df_c=pd.concat(frames)

# %%
df_c.head()
# Out:
#            ts                 uid        id.orig_h  id.orig_p  \
# 0  1525879836  CgeVK21nm6PyVgJ4ah  192.168.100.103    40973.0
# 1  1525879837  CFXxTW19F3sluNEkJk  192.168.100.103    52259.0
# 2  1525879838  CRRl9U39PzvL3OiS61  192.168.100.103    42207.0
# 3  1525879838  C9hk4p2z9Y6AvlzLff  192.168.100.103    51524.0
# 4  1525879839  Cx7t1f1wqRES8kiTq6  192.168.100.103    40459.0
#
#          id.resp_h  id.resp_p proto service  duration orig_bytes  ...  \
# 0   62.239.193.205     8080.0   tcp       -         -          -  ...
# 1  193.189.106.178       23.0   tcp       -    2.9993          0  ...
# 2    10.169.219.98     8080.0   tcp       -  2.993548          0  ...
# 3   65.127.233.163       23.0   tcp       -         -          -  ...
# 4  212.110.180.188       23.0   tcp       -  2.998807          0  ...
#
#   local_orig local_resp missed_bytes history  orig_pkts orig_ip_bytes  \
# 0          -          -          0.0       S        1.0          60.0
# 1          -          -          0.0       S        3.0         180.0
# 2          -          -          0.0       S        3.0         180.0
# 3          -          -          0.0       S        1.0          60.0
# 4          -          -          0.0       S        3.0         180.0
#
#    resp_pkts  resp_ip_bytes                                            label  \
# 0        0.0            0.0  (empty)   Malicious   PartOfAHorizontalPortScan
# 1        0.0            0.0  (empty)   Malicious   PartOfAHorizontalPortScan
# 2        0.0            0.0  (empty)   Malicious   PartOfAHorizontalPortScan
# 3        0.0            0.0  (empty)   Malicious   PartOfAHorizontalPortScan
# 4        0.0            0.0  (empty)   Malicious   PartOfAHorizontalPortScan
#
#    tunnel_parents
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 22 columns]

# %%
df_c.shape
# Out:
# (225087, 22)

# %%
df_c['label'].value_counts()
# Out:
# -   Malicious   Okiru                              99864
# (empty)   Malicious   PartOfAHorizontalPortScan    55041
# (empty)   Benign   -                               44958
# -   Malicious   DDoS                               14394
# -   Malicious   C&C                                 6706
# -   benign   -                                      1947
# -   Benign   -                                      1941
# -   Malicious   PartOfAHorizontalPortScan            122
# -   Malicious   C&C-HeartBeat                        114
# Name: label, dtype: int64

# %%
df_c.loc[(df_c.label == '-   Malicious   PartOfAHorizontalPortScan'), 'label'] = 'POHScan'
df_c.loc[(df_c.label == '(empty)   Malicious   PartOfAHorizontalPortScan'), 'label'] = 'POHScan'
df_c.loc[(df_c.label == '-   Malicious   Okiru'), 'label'] = 'Okiru'
df_c.loc[(df_c.label == '(empty)   Malicious   Okiru'), 'label'] = 'Okiru'
df_c.loc[(df_c.label == '-   Benign   -'), 'label'] = 'Benign'
df_c.loc[(df_c.label == '(empty)   Benign   -'), 'label'] = 'Benign'
df_c.loc[(df_c.label == '-   benign   -'), 'label'] = 'Benign'
df_c.loc[(df_c.label == '-   Malicious   DDoS'), 'label'] = 'DDoS'
df_c.loc[(df_c.label == '-   Malicious   C&C'), 'label'] = 'C&C'
df_c.loc[(df_c.label == '(empty)   Malicious   C&C'), 'label'] = 'C&C'
df_c.loc[(df_c.label == '-   Malicious   Attack'), 'label'] = 'Attack'
df_c.loc[(df_c.label == '(empty)   Malicious   Attack'), 'label'] = 'Attack'
df_c.loc[(df_c.label == '-   Malicious   C&C-HeartBeat'), 'label'] = 'C&C-HeartBeat'
df_c.loc[(df_c.label == '(empty)   Malicious   C&C-HeartBeat'), 'label'] = 'C&C-HeartBeat'
df_c.loc[(df_c.label == '-   Malicious   C&C-FileDownload'), 'label'] = 'C&C-FileDownload'
df_c.loc[(df_c.label == '-   Malicious   C&C-Torii'), 'label'] = 'C&C-Torii'
df_c.loc[(df_c.label == '-   Malicious   C&C-HeartBeat-FileDownload'), 'label'] = 'C&C-HeartBeat-FileDownload'
df_c.loc[(df_c.label == '-   Malicious   FileDownload'), 'label'] = 'FileDownload'
df_c.loc[(df_c.label == '-   Malicious   C&C-Mirai'), 'label'] = 'C&C-Mirai'
df_c.loc[(df_c.label == '-   Malicious   Okiru-Attack'), 'label'] = 'Okiru-Attack'

# %%
df_c['label'].value_counts()
# Out:
# Okiru            99864
# POHScan          55163
# Benign           48846
# DDoS             14394
# C&C               6706
# C&C-HeartBeat      114
# Name: label, dtype: int64

# %%
df_c.shape
# Out:
# (225087, 22)

# %%
df_c.to_csv('iot23_combined_new_2lac.csv')
