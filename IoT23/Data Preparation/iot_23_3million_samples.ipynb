# %%
import os
import numpy as np
import pandas as pd
import csv
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Import data

# %%
capture_60 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-60-1/bro/conn.log.labeled"
capture_17 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-17-1/bro/conn.log.labeled"
capture_36 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-36-1/bro/conn.log.labeled"
capture_34 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-34-1/bro/conn.log.labeled"
capture_39 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-39-1/bro/conn.log.labeled"
capture_9 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-9-1/bro/conn.log.labeled"
capture_3 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-3-1/bro/conn.log.labeled"
capture_1 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-1-1/bro/conn.log.labeled"
capture_8 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-8-1/bro/conn.log.labeled"
capture_20 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-20-1/bro/conn.log.labeled"
capture_21 = "D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-21-1/bro/conn.log.labeled"

# %%
honeypot_1= "D:/Final Theses Project/Research Paper/Dataset/HoneyPot/CTU-Honeypot-Capture-4-1/bro/conn.log.labeled"
honeypot_2= "D:/Final Theses Project/Research Paper/Dataset/HoneyPot/CTU-Honeypot-Capture-5-1/bro/conn.log.labeled"
honeypot_3= "D:/Final Theses Project/Research Paper/Dataset/HoneyPot/CTU-Honeypot-Capture-7-1/Somfy-01/bro/conn.log.labeled"

# %%
df1 = pd.read_table(filepath_or_buffer=capture_1, skiprows=10, nrows=1000000)
df1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
                'label',
            'detailed_label']
df1.drop(df1.tail(1).index,inplace=True)

# %%
df1.head()
# Out:
#            ts                 uid        id.orig_h  id.orig_p  \
# 0  1525879836  CgeVK21nm6PyVgJ4ah  192.168.100.103      40973
# 1  1525879837  CFXxTW19F3sluNEkJk  192.168.100.103      52259
# 2  1525879838  CRRl9U39PzvL3OiS61  192.168.100.103      42207
# 3  1525879838  C9hk4p2z9Y6AvlzLff  192.168.100.103      51524
# 4  1525879839  Cx7t1f1wqRES8kiTq6  192.168.100.103      40459
#
#          id.resp_h  id.resp_p proto service  duration orig_bytes  ...  \
# 0   62.239.193.205       8080   tcp       -         -          -  ...
# 1  193.189.106.178         23   tcp       -    2.9993          0  ...
# 2    10.169.219.98       8080   tcp       -  2.993548          0  ...
# 3   65.127.233.163         23   tcp       -         -          -  ...
# 4  212.110.180.188         23   tcp       -  2.998807          0  ...
#
#   local_orig local_resp missed_bytes history  orig_pkts orig_ip_bytes  \
# 0          -          -            0       S          1            60
# 1          -          -            0       S          3           180
# 2          -          -            0       S          3           180
# 3          -          -            0       S          1            60
# 4          -          -            0       S          3           180
#
#    resp_pkts  resp_ip_bytes                                            label  \
# 0          0              0  (empty)   Malicious   PartOfAHorizontalPortScan
# 1          0              0  (empty)   Malicious   PartOfAHorizontalPortScan
# 2          0              0  (empty)   Malicious   PartOfAHorizontalPortScan
# 3          0              0  (empty)   Malicious   PartOfAHorizontalPortScan
# 4          0              0  (empty)   Malicious   PartOfAHorizontalPortScan
#
#    detailed_label
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 22 columns]

# %%
df1.shape
# Out:
# (984740, 22)

# %%
df1['label'].value_counts()
# Out:
# (empty)   Malicious   PartOfAHorizontalPortScan    526894
# (empty)   Benign   -                               457838
# (empty)   Malicious   C&C                               8
# Name: label, dtype: int64

# %%
df3 = pd.read_table(filepath_or_buffer=capture_3, skiprows=10, nrows=200000)
df3.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
                'label',
              'detailed_label']
df3.drop(df3.tail(1).index,inplace=True)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df3.head()
# Out:
#            ts                 uid    id.orig_h  id.orig_p       id.resp_h  \
# 0  1526756317   C7NAoZ1GBUXpxV0sX  192.168.2.5    38797.0  200.168.87.203
# 1  1526756324   C8zmT04Y5NIOLxp0y  192.168.2.5    38797.0  200.168.87.203
# 2  1526756328   Ch70sn1L7zuOI4Qnc  192.168.2.5    38798.0  200.168.87.203
# 3  1526756278  CuOSYz3QNAKPuLEOXg  192.168.2.5      123.0  78.108.102.237
# 4  1526756243   Cr32XW1idd6BFFTCq  192.168.2.5      123.0  37.157.198.150
#
#    id.resp_p proto service   duration orig_bytes  ... local_orig local_resp  \
# 0    59353.0   tcp       -   2.998315          0  ...          -          -
# 1    59353.0   tcp       -          -          -  ...          -          -
# 2    59353.0   tcp       -   2.999395          0  ...          -          -
# 3      123.0   udp       -   0.012703         48  ...          -          -
# 4      123.0   udp       -  35.017664        288  ...          -          -
#
#   missed_bytes history  orig_pkts orig_ip_bytes  resp_pkts  resp_ip_bytes  \
# 0          0.0       S        3.0         180.0        0.0            0.0
# 1          0.0       S        1.0          60.0        0.0            0.0
# 2          0.0       S        3.0         180.0        0.0            0.0
# 3          0.0      Dd        1.0          76.0        1.0           76.0
# 4          0.0      Dd        6.0         456.0        6.0          456.0
#
#                                              label  detailed_label
# 0  (empty)   Malicious   PartOfAHorizontalPortScan             NaN
# 1  (empty)   Malicious   PartOfAHorizontalPortScan             NaN
# 2  (empty)   Malicious   PartOfAHorizontalPortScan             NaN
# 3                             (empty)   Benign   -             NaN
# 4                             (empty)   Benign   -             NaN
#
# [5 rows x 22 columns]

# %%
df8 = pd.read_table(filepath_or_buffer=capture_8, skiprows=10, nrows=200000)
df8.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df8.drop(df8.tail(1).index,inplace=True)

# %%
df9 = pd.read_table(filepath_or_buffer=capture_9, skiprows=10, nrows=500000)
df9.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df9.drop(df9.tail(1).index,inplace=True)

# %%
df9.head()
# Out:
#              ts                 uid        id.orig_h  id.orig_p  \
# 0  1.532512e+09   CFr56iYeYk4YZXrPf  192.168.100.102      59701
# 1  1.532512e+09  C8a9xW23hF8nDgeNtj  192.168.100.111      36199
# 2  1.532512e+09  COstHQ2pRfPLaMVBs7  192.168.100.111      48089
# 3  1.532512e+09  C9hLCM10ThJFO30bl9  192.168.100.111      49635
# 4  1.532512e+09  CfBUIS3oDR0u4PJwP3  192.168.100.111      60894
#
#          id.resp_h  id.resp_p proto service  duration orig_bytes  ...  \
# 0  192.168.100.111         22   tcp       -  0.000738         21  ...
# 1    192.168.100.1         53   udp     dns         -          -  ...
# 2    192.168.100.1         53   udp     dns         -          -  ...
# 3    192.168.100.1         53   udp     dns  0.027739         30  ...
# 4    192.168.100.1         53   udp     dns         -          -  ...
#
#   conn_state local_orig local_resp missed_bytes  history orig_pkts  \
# 0         S0          -          -            0      SAD         3
# 1         S0          -          -            0        D         1
# 2         S0          -          -            0        D         1
# 3         SF          -          -            0       Dd         1
# 4         S0          -          -            0        D         1
#
#    orig_ip_bytes  resp_pkts  resp_ip_bytes                 label
# 0            189          0              0  (empty)   Benign   -
# 1             58          0              0  (empty)   Benign   -
# 2             58          0              0  (empty)   Benign   -
# 3             58          1            122  (empty)   Benign   -
# 4             65          0              0  (empty)   Benign   -
#
# [5 rows x 21 columns]

# %%
df9['label'].value_counts()
# Out:
# (empty)   Malicious   PartOfAHorizontalPortScan    497484
# (empty)   Benign   -                                 2515
# Name: label, dtype: int64

# %%
df17 = pd.read_table(filepath_or_buffer=capture_17, skiprows=10, nrows=200000)
df17.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df17.drop(df17.tail(1).index,inplace=True)

# %%
df20 = pd.read_table(filepath_or_buffer=capture_20, skiprows=10, nrows=500000)
df20.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df20.drop(df20.tail(1).index,inplace=True)

# %%
df21 = pd.read_table(filepath_or_buffer=capture_21, skiprows=10, nrows=200000)
df21.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df21.drop(df21.tail(1).index,inplace=True)

# %%
df34 = pd.read_table(filepath_or_buffer=capture_34, skiprows=10, nrows=500000)
df34.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
                'label']
df34.drop(df34.tail(1).index,inplace=True)

# %%
df36 = pd.read_table(filepath_or_buffer=capture_36, skiprows=10, nrows=500000)
df36.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df36.drop(df36.tail(1).index,inplace=True)

# %%
df39 = pd.read_table(filepath_or_buffer=capture_39, skiprows=10, nrows=200000)
df39.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df39.drop(df39.tail(1).index,inplace=True)

# %%
df60 = pd.read_table(filepath_or_buffer=capture_60, skiprows=10, nrows=200000)
df60.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df60.drop(df60.tail(1).index,inplace=True)

# %%
df34 = pd.read_table(filepath_or_buffer=capture_60, skiprows=10, nrows=200000)
df34.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df34.drop(df34.tail(1).index,inplace=True)

# %% [markdown]
# # Benign Data Scenarios

# %%
df_h1 = pd.read_table(filepath_or_buffer=honeypot_1, skiprows=10, nrows=100000)
df_h1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df_h1.drop(df_h1.tail(1).index,inplace=True)

# %%
df_h2 = pd.read_table(filepath_or_buffer=honeypot_2, skiprows=10, nrows=100000)
df_h2.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df_h2.drop(df_h2.tail(1).index,inplace=True)

# %%
df_h3 = pd.read_table(filepath_or_buffer=honeypot_3, skiprows=10, nrows=100000)
df_h3.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df_h3.drop(df_h3.tail(1).index,inplace=True)

# %% [markdown]
# # Joining all the dataframes

# %%
frames=[df17, df20, df21,df34, df36, df39, df60, df8, df9,df1, df_h1, df_h2, df_h3]

# %%
df_c=pd.concat(frames)

# %%
df_c.head()
# Out:
#             ts                 uid        id.orig_h  id.orig_p  \
# 0  1.53623e+09  CeqqKl3hyLQmO8LK98  192.168.100.111    17576.0
# 1  1.53623e+09   C2oHQWo1EFGH8D9x7  192.168.100.111    17576.0
# 2  1.53623e+09  CJLVjs4BByG04mczXc  192.168.100.111    17576.0
# 3  1.53623e+09   C0z4uS9AWHDH2s4S7  192.168.100.111    17576.0
# 4  1.53623e+09  CxbNVk3liFNUIlqSPi  192.168.100.111    17576.0
#
#         id.resp_h  id.resp_p proto service duration orig_bytes  ...  \
# 0    78.1.220.212     8081.0   tcp       -    3e-06          0  ...
# 1    152.84.7.111     8081.0   tcp       -    2e-06          0  ...
# 2    173.36.41.67     8081.0   tcp       -    2e-06          0  ...
# 3    87.13.21.104     8081.0   tcp       -    2e-06          0  ...
# 4  99.110.163.140     8081.0   tcp       -    2e-06          0  ...
#
#   local_orig local_resp missed_bytes history  orig_pkts orig_ip_bytes  \
# 0          -          -          0.0       S        2.0          80.0
# 1          -          -          0.0       S        2.0          80.0
# 2          -          -          0.0       S        2.0          80.0
# 3          -          -          0.0       S        2.0          80.0
# 4          -          -          0.0       S        2.0          80.0
#
#    resp_pkts  resp_ip_bytes                                      label  \
# 0        0.0            0.0  -   Malicious   PartOfAHorizontalPortScan
# 1        0.0            0.0  -   Malicious   PartOfAHorizontalPortScan
# 2        0.0            0.0  -   Malicious   PartOfAHorizontalPortScan
# 3        0.0            0.0  -   Malicious   PartOfAHorizontalPortScan
# 4        0.0            0.0  -   Malicious   PartOfAHorizontalPortScan
#
#    detailed_label
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 22 columns]

# %%
df_c.shape
# Out:
# (2803570, 22)

# %%
df_c['label'].value_counts()
# Out:
# (empty)   Malicious   PartOfAHorizontalPortScan    1024378
# -   Malicious   Okiru                               549228
# (empty)   Benign   -                                462531
# -   Malicious   DDoS                                448703
# -   Malicious   PartOfAHorizontalPortScan           299887
# (empty)   Malicious   C&C                             8230
# -   Benign   -                                        7841
# -   benign   -                                        1947
# -   Malicious   C&C-HeartBeat                          782
# -   Malicious   C&C-Torii                               30
# -   Malicious   C&C                                     10
# -   Malicious   Okiru-Attack                             3
# Name: label, dtype: int64

# %%
df_c.loc[(df_c.label == '-   Malicious   PartOfAHorizontalPortScan'), 'label'] = 'POHScan'
df_c.loc[(df_c.label == '(empty)   Malicious   PartOfAHorizontalPortScan'), 'label'] = 'POHScan'
df_c.loc[(df_c.label == '-   Malicious   Okiru'), 'label'] = 'Okiru'
df_c.loc[(df_c.label == '(empty)   Malicious   Okiru'), 'label'] = 'Okiru'
df_c.loc[(df_c.label == '-   Benign   -'), 'label'] = 'Benign'
df_c.loc[(df_c.label == '(empty)   Benign   -'), 'label'] = 'Benign'
df_c.loc[(df_c.label == '-   benign   -'), 'label'] = 'Benign'
df_c.loc[(df_c.label == '-   Malicious   DDoS'), 'label'] = 'DDoS'
df_c.loc[(df_c.label == '-   Malicious   C&C'), 'label'] = 'C&C'
df_c.loc[(df_c.label == '(empty)   Malicious   C&C'), 'label'] = 'C&C'
df_c.loc[(df_c.label == '-   Malicious   Attack'), 'label'] = 'Attack'
df_c.loc[(df_c.label == '(empty)   Malicious   Attack'), 'label'] = 'Attack'
df_c.loc[(df_c.label == '-   Malicious   C&C-HeartBeat'), 'label'] = 'C&C-HeartBeat'
df_c.loc[(df_c.label == '(empty)   Malicious   C&C-HeartBeat'), 'label'] = 'C&C-HeartBeat'
df_c.loc[(df_c.label == '-   Malicious   C&C-FileDownload'), 'label'] = 'C&C-FileDownload'
df_c.loc[(df_c.label == '-   Malicious   C&C-Torii'), 'label'] = 'C&C-Torii'
df_c.loc[(df_c.label == '-   Malicious   C&C-HeartBeat-FileDownload'), 'label'] = 'C&C-HeartBeat-FileDownload'
df_c.loc[(df_c.label == '-   Malicious   FileDownload'), 'label'] = 'FileDownload'
df_c.loc[(df_c.label == '-   Malicious   C&C-Mirai'), 'label'] = 'C&C-Mirai'
df_c.loc[(df_c.label == '-   Malicious   Okiru-Attack'), 'label'] = 'Okiru-Attack'

# %%
df_c['label'].value_counts()
# Out:
# POHScan          1324265
# Okiru             549228
# Benign            472319
# DDoS              448703
# C&C                 8240
# C&C-HeartBeat        782
# C&C-Torii             30
# Okiru-Attack           3
# Name: label, dtype: int64

# %%
df_c.to_csv('iot23_combined_new_3M.csv')
