# %%
import os
import numpy as np
import pandas as pd
import csv
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import zat
from zat.log_to_dataframe import LogToDataFrame
from zat.dataframe_to_matrix import DataFrameToMatrix
print('zat: {:s}'.format(zat.__version__))
import pandas as pd
print('Pandas: {:s}'.format(pd.__version__))
import numpy as np
print('Numpy: {:s}'.format(np.__version__))
import sklearn
from sklearn.ensemble import IsolationForest
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
print('Scikit Learn Version:', sklearn.__version__)
# Out:
# zat: 0.4.4
# Pandas: 1.1.3
# Numpy: 1.19.2
# Scikit Learn Version: 1.0.2

# %%
# Create a Pandas dataframe from the Zeek  log
log_to_df = LogToDataFrame()

# %%
df60 = log_to_df.create_dataframe('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-60-1/bro/conn.log.labeled')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-6b4da84da82b> in <module>
# ----> 1 df60 = log_to_df.create_dataframe('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-60-1/bro/conn.log.labeled',delimiter=None)
#
# TypeError: create_dataframe() got an unexpected keyword argument 'delimiter'

# %%
df60.head()
# Out:
#                                               uid      id.orig_h  id.orig_p  \
# ts
# 2019-09-20 00:40:58.775321960  CEjjLs1iwWYrt8C4O6  192.168.1.195        123
# 2019-09-20 00:41:59.775273085  CHNzmm3tMu5Gse9Zvg  192.168.1.195        123
# 2019-09-20 00:43:51.016249895   CDlbowGNUwsHckADd  192.168.1.195      37120
# 2019-09-20 00:40:41.665907145  CxKxhj4MGsf5GcqoX6    192.168.1.1      47805
# 2019-09-20 00:44:11.392718077  C2n3PK3bA92hAgTHda  192.168.1.195      37122
#
#                                     id.resp_h  id.resp_p proto service  \
# ts
# 2019-09-20 00:40:58.775321960  212.111.30.190        123   udp     NaN
# 2019-09-20 00:41:59.775273085  89.221.218.101        123   udp     NaN
# 2019-09-20 00:43:51.016249895   102.165.48.81      17769   tcp     NaN
# 2019-09-20 00:40:41.665907145   192.168.1.195         22   tcp     NaN
# 2019-09-20 00:44:11.392718077   102.165.48.81      17769   tcp     NaN
#
#                                             duration  orig_bytes  resp_bytes  \
# ts
# 2019-09-20 00:40:58.775321960 0 days 00:00:00.008239          96          96
# 2019-09-20 00:41:59.775273085 0 days 00:00:00.007496          96          96
# 2019-09-20 00:43:51.016249895 0 days 00:00:01.848549         518          66
# 2019-09-20 00:40:41.665907145 0 days 00:03:26.663644        2768       11216
# 2019-09-20 00:44:11.392718077 0 days 00:00:01.902519         518          66
#
#                               conn_state local_orig local_resp  missed_bytes  \
# ts
# 2019-09-20 00:40:58.775321960         SF        NaN        NaN             0
# 2019-09-20 00:41:59.775273085         SF        NaN        NaN             0
# 2019-09-20 00:43:51.016249895       RSTR        NaN        NaN             0
# 2019-09-20 00:40:41.665907145         SF        NaN        NaN             0
# 2019-09-20 00:44:11.392718077       RSTR        NaN        NaN             0
#
#                                history  orig_pkts  orig_ip_bytes  resp_pkts  \
# ts
# 2019-09-20 00:40:58.775321960       Dd          2            152          2
# 2019-09-20 00:41:59.775273085       Dd          2            152          2
# 2019-09-20 00:43:51.016249895  ShAdfDr         10           1572          8
# 2019-09-20 00:40:41.665907145   DdAaFf        400          26336        268
# 2019-09-20 00:44:11.392718077  ShAdfDr         10           1572          8
#
#                                resp_ip_bytes  \
# ts
# 2019-09-20 00:40:58.775321960            152
# 2019-09-20 00:41:59.775273085            152
# 2019-09-20 00:43:51.016249895            540
# 2019-09-20 00:40:41.665907145          36368
# 2019-09-20 00:44:11.392718077            540
#
#                               tunnel_parents   label   detailed-label
# ts
# 2019-09-20 00:40:58.775321960                          -   Benign   -
# 2019-09-20 00:41:59.775273085                          -   Benign   -
# 2019-09-20 00:43:51.016249895           -   Malicious   C&C-HeartBeat
# 2019-09-20 00:40:41.665907145                          -   Benign   -
# 2019-09-20 00:44:11.392718077           -   Malicious   C&C-HeartBeat

# %%
df60.shape
# Out:
# (3581028, 20)
