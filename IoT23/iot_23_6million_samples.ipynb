# %%
import os
import numpy as np
import pandas as pd
import csv
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-1-1/bro/conn.log.labeled',sep='[\t ' ']', engine='python')

# %%
df3 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-3-1/bro/conn.log.labeled',sep='[\t ' ']', engine='python')

# %%
df7 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-7-1/bro/conn.log.labeled',sep='[\t ' ' ]', engine='python',nrows=200000)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-26-e8a73114675e> in <module>
# ----> 1 df7 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-7-1/bro/conn.log.labeled',sep='[\t ' ' ]', engine='python',nrows=200000)
#
# ...

# %%
label.value_counts()
# Out:
# PartOfAHorizontalPortScan    526903
# -                            457840
# C&C                               8
# Name: Unnamed: 26, dtype: int64

# %%
df43 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-43-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
df44 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-44-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
df49 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-49-1/bro/conn.log.labeled', sep='[\t ' ']',engine='python')
df52 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-52-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
df20 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-20-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
df21 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-21-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')

# %%
df43 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-43-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
df44 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-44-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
df49 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-49-1/bro/conn.log.labeled', sep='[\t ' ']',engine='python')
df52 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-52-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
df20 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-20-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
df21 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-21-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
df42 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-42-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
df60 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-60-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
df17 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-17-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
df36 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-36-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
df33 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-33-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
df8 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-8-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
df35 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-35-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
df48 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-48-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
df39 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-39-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
df7 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-7-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
df9 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-9-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
df3 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-3-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
hp1 = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-1-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
hp1= pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/HoneyPot/CTU-Honeypot-Capture-4-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
hp2= pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/HoneyPot/CTU-Honeypot-Capture-5-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')
hp3= pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/HoneyPot/CTU-Honeypot-Capture-7-1/Somfy-01/bro/conn.log.labeled', sep='[\t ' ']', engine='python')

# %%
df_raw = open(r'D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-1-1/bro/conn.log.labeled')

# %%
df_raw = pd.read_csv('D:/Final Theses Project/Research Paper/Dataset/Malware/CTU-IoT-Malware-Capture-1-1/bro/conn.log.labeled', sep='[\t ' ']', engine='python')

# %%
df_raw
# Out:
#            #fields                  ts              uid  id.orig_h  \
# 0       1525879831  CUmrqr4svHuSXJy5z7  192.168.100.103      51524
# 1       1525879831  CH98aB3s1kJeq6SFOc  192.168.100.103      56305
# 2       1525879831   C3GBTkINvXNjVGtN5  192.168.100.103      41101
# 3       1525879832   CDe43c1PtgynajGI6  192.168.100.103      60905
# 4       1525879832  CJaDcG3MZzvf1YVYI4  192.168.100.103      44301
# ...            ...                 ...              ...        ...
# 984746  1526272359  Cy2T0E2xY0IHiSzQY8  192.168.100.103      53287
# 984747  1526272304  CznDIu43LcbgxLuKsg  192.168.100.103      43763
# 984748  1526272359  CbAOpL31xpgmOktlki  192.168.100.103      55849
# 984749  1526272305  CpwPuI1LJ9VGWLZzvh  192.168.100.103      43763
# 984750  1526272360   CV7uKRj6dm2jZ4vW1  192.168.100.103      53126
#
#               id.orig_p  id.resp_h id.resp_p proto   service duration  ...  \
# 0        65.127.233.163         23       tcp     -  2.999051        0  ...
# ...

# %%
df1 = pd.read_table(filepath_or_buffer=capture_1, skiprows=10, nrows=20000)
df1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
             'tunnel_parents',
              'label',
            'detailed-label']
df1.drop(df1.tail(1).index,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-b682b259c120> in <module>
#       1 df1 = pd.read_table(filepath_or_buffer=capture_1, skiprows=10, nrows=500000)
# ----> 2 df1.columns=['ts',
#       3               'uid',
#       4               'id.orig_h',
#       5               'id.orig_p',
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
# ...

# %%
df1.head()
# Out:
#            ts                 uid        id.orig_h  id.orig_p  \
# 0  1525879836  CgeVK21nm6PyVgJ4ah  192.168.100.103      40973
# 1  1525879837  CFXxTW19F3sluNEkJk  192.168.100.103      52259
# 2  1525879838  CRRl9U39PzvL3OiS61  192.168.100.103      42207
# 3  1525879838  C9hk4p2z9Y6AvlzLff  192.168.100.103      51524
# 4  1525879839  Cx7t1f1wqRES8kiTq6  192.168.100.103      40459
#
#          id.resp_h  id.resp_p proto service  duration orig_bytes  ...  \
# 0   62.239.193.205       8080   tcp       -         -          -  ...
# 1  193.189.106.178         23   tcp       -    2.9993          0  ...
# 2    10.169.219.98       8080   tcp       -  2.993548          0  ...
# 3   65.127.233.163         23   tcp       -         -          -  ...
# 4  212.110.180.188         23   tcp       -  2.998807          0  ...
#
#   local_orig local_resp missed_bytes history  orig_pkts orig_ip_bytes  \
# 0          -          -            0       S          1            60
# ...

# %%
df3 = pd.read_table(filepath_or_buffer=capture_3, skiprows=10, nrows=500000)
df3.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
             'tunnel_parents',
              'label']
df3.drop(df3.tail(1).index,inplace=True)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df3.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-88ce1073d687> in <module>
# ----> 1 df3.head()
#
# NameError: name 'df3' is not defined

# %%
df7 = pd.read_table(filepath_or_buffer=capture_7, skiprows=10, nrows=500000)
df7.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df7.drop(df7.tail(1).index,inplace=True)

# %%
df8 = pd.read_table(filepath_or_buffer=capture_8, skiprows=10, nrows=100000)
df8.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df8.drop(df8.tail(1).index,inplace=True)

# %%
df9 = pd.read_table(filepath_or_buffer=capture_9, skiprows=10, nrows=500000)
df9.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df9.drop(df9.tail(1).index,inplace=True)

# %%
df17 = pd.read_table(filepath_or_buffer=capture_17, skiprows=10, nrows=500000)
df17.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df17.drop(df17.tail(1).index,inplace=True)

# %%
df20 = pd.read_table(filepath_or_buffer=capture_20, skiprows=10, nrows=500000)
df20.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df20.drop(df20.tail(1).index,inplace=True)

# %%
df21 = pd.read_table(filepath_or_buffer=capture_21, skiprows=10, nrows=500000)
df21.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df21.drop(df21.tail(1).index,inplace=True)

# %%
df33 = pd.read_table(filepath_or_buffer=capture_33, skiprows=10, nrows=500000)
df33.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df33.drop(df33.tail(1).index,inplace=True)

# %%
df34 = pd.read_table(filepath_or_buffer=capture_34, skiprows=10, nrows=500000)
df34.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
                'label']
df34.drop(df34.tail(1).index,inplace=True)

# %%
df35 = pd.read_table(filepath_or_buffer=capture_35, skiprows=10, nrows=500000)
df35.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df35.drop(df35.tail(1).index,inplace=True)

# %%
df36 = pd.read_table(filepath_or_buffer=capture_36, skiprows=10, nrows=500000)
df36.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df36.drop(df36.tail(1).index,inplace=True)

# %%
df39 = pd.read_table(filepath_or_buffer=capture_39, skiprows=10, nrows=500000)
df39.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df39.drop(df39.tail(1).index,inplace=True)

# %%
df42 = pd.read_table(filepath_or_buffer=capture_42, skiprows=10, nrows=500000)
df42.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df42.drop(df42.tail(1).index,inplace=True)

# %%
df43 = pd.read_table(filepath_or_buffer=capture_43, skiprows=10, nrows=500000)
df43.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df43.drop(df43.tail(1).index,inplace=True)

# %%
df44 = pd.read_table(filepath_or_buffer=capture_44, skiprows=10, nrows=500000)
df44.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df44.drop(df44.tail(1).index,inplace=True)

# %%
df48 = pd.read_table(filepath_or_buffer=capture_48, skiprows=10, nrows=500000)
df48.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df48.drop(df48.tail(1).index,inplace=True)

# %%
df49 = pd.read_table(filepath_or_buffer=capture_49, skiprows=10, nrows=500000)
df49.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df49.drop(df49.tail(1).index,inplace=True)

# %%
df52 = pd.read_table(filepath_or_buffer=capture_52, skiprows=10, nrows=500000)
df52.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df52.drop(df52.tail(1).index,inplace=True)

# %%
df60 = pd.read_table(filepath_or_buffer=capture_60, skiprows=10, nrows=500000)
df60.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df60.drop(df60.tail(1).index,inplace=True)

# %% [markdown]
# # Benign Data Scenarios

# %%
df_h1 = pd.read_table(filepath_or_buffer=honeypot_1, skiprows=10, nrows=100000)
df_h1.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df_h1.drop(df_h1.tail(1).index,inplace=True)

# %%
df_h2 = pd.read_table(filepath_or_buffer=honeypot_2, skiprows=10, nrows=100000)
df_h2.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df_h2.drop(df_h2.tail(1).index,inplace=True)

# %%
df_h3 = pd.read_table(filepath_or_buffer=honeypot_3, skiprows=10, nrows=100000)
df_h3.columns=['ts',
              'uid',
              'id.orig_h',
              'id.orig_p',
              'id.resp_h',
              'id.resp_p',
              'proto',
              'service',
              'duration',
              'orig_bytes',
              'resp_bytes',
              'conn_state',
              'local_orig',
              'local_resp',
              'missed_bytes',
              'history',
              'orig_pkts',
              'orig_ip_bytes',
              'resp_pkts',
              'resp_ip_bytes',
              'label']
df_h3.drop(df_h3.tail(1).index,inplace=True)

# %% [markdown]
# # Joining all the dataframes

# %%
frames=[df17, df20, df21, df33, df34, df35, df36, df39, df42, df43, df44, df48, df49, df52, df60, df7, df8, df9, df_h1, df_h2, df_h3 ]

# %%
df_c=pd.concat(frames)

# %%
df_c.head()
# Out:
#             ts                 uid        id.orig_h  id.orig_p  \
# 0  1.53623e+09  CeqqKl3hyLQmO8LK98  192.168.100.111    17576.0
# 1  1.53623e+09   C2oHQWo1EFGH8D9x7  192.168.100.111    17576.0
# 2  1.53623e+09  CJLVjs4BByG04mczXc  192.168.100.111    17576.0
# 3  1.53623e+09   C0z4uS9AWHDH2s4S7  192.168.100.111    17576.0
# 4  1.53623e+09  CxbNVk3liFNUIlqSPi  192.168.100.111    17576.0
#
#         id.resp_h  id.resp_p proto service duration orig_bytes  ...  \
# 0    78.1.220.212     8081.0   tcp       -    3e-06          0  ...
# 1    152.84.7.111     8081.0   tcp       -    2e-06          0  ...
# 2    173.36.41.67     8081.0   tcp       -    2e-06          0  ...
# 3    87.13.21.104     8081.0   tcp       -    2e-06          0  ...
# 4  99.110.163.140     8081.0   tcp       -    2e-06          0  ...
#
#   conn_state local_orig local_resp missed_bytes  history orig_pkts  \
# 0         S0          -          -          0.0        S       2.0
# ...

# %%
df_c.shape
# Out:
# (6046623, 21)

# %%
df_c['label'].value_counts()
# Out:
# -   Malicious   PartOfAHorizontalPortScan          2891552
# -   Malicious   Okiru                               814242
# -   Benign   -                                      681511
# -   Malicious   DDoS                                638506
# (empty)   Malicious   Okiru                         498770
# (empty)   Malicious   PartOfAHorizontalPortScan     497484
# (empty)   Malicious   C&C                             8222
# -   Malicious   C&C                                   7064
# (empty)   Benign   -                                  5354
# -   benign   -                                        1947
# -   Malicious   C&C-HeartBeat                          764
# (empty)   Malicious   C&C-HeartBeat                    568
# -   Malicious   Attack                                 538
# -   Malicious   C&C-FileDownload                        46
# -   Malicious   C&C-Torii                               30
# -   Malicious   FileDownload                            13
# ...

# %%
df_c.loc[(df_c.label == '-   Malicious   PartOfAHorizontalPortScan'), 'label'] = 'PartOfAHorizontalPortScan'
df_c.loc[(df_c.label == '(empty)   Malicious   PartOfAHorizontalPortScan'), 'label'] = 'PartOfAHorizontalPortScan'
df_c.loc[(df_c.label == '-   Malicious   Okiru'), 'label'] = 'Okiru'
df_c.loc[(df_c.label == '(empty)   Malicious   Okiru'), 'label'] = 'Okiru'
df_c.loc[(df_c.label == '-   Benign   -'), 'label'] = 'Benign'
df_c.loc[(df_c.label == '(empty)   Benign   -'), 'label'] = 'Benign'
df_c.loc[(df_c.label == '-   benign   -'), 'label'] = 'Benign'
df_c.loc[(df_c.label == '-   Malicious   DDoS'), 'label'] = 'DDoS'
df_c.loc[(df_c.label == '-   Malicious   C&C'), 'label'] = 'C&C'
df_c.loc[(df_c.label == '(empty)   Malicious   C&C'), 'label'] = 'C&C'
df_c.loc[(df_c.label == '-   Malicious   Attack'), 'label'] = 'Attack'
df_c.loc[(df_c.label == '(empty)   Malicious   Attack'), 'label'] = 'Attack'
df_c.loc[(df_c.label == '-   Malicious   C&C-HeartBeat'), 'label'] = 'C&C-HeartBeat'
df_c.loc[(df_c.label == '(empty)   Malicious   C&C-HeartBeat'), 'label'] = 'C&C-HeartBeat'
df_c.loc[(df_c.label == '-   Malicious   C&C-FileDownload'), 'label'] = 'C&C-FileDownload'
df_c.loc[(df_c.label == '-   Malicious   C&C-Torii'), 'label'] = 'C&C-Torii'
df_c.loc[(df_c.label == '-   Malicious   C&C-HeartBeat-FileDownload'), 'label'] = 'C&C-HeartBeat-FileDownload'
df_c.loc[(df_c.label == '-   Malicious   FileDownload'), 'label'] = 'FileDownload'
df_c.loc[(df_c.label == '-   Malicious   C&C-Mirai'), 'label'] = 'C&C-Mirai'
df_c.loc[(df_c.label == '-   Malicious   Okiru-Attack'), 'label'] = 'Okiru-Attack'

# %%
df_c['label'].value_counts()
# Out:
# PartOfAHorizontalPortScan     3389036
# Okiru                         1313012
# Benign                         688812
# DDoS                           638506
# C&C                             15286
# C&C-HeartBeat                    1332
# Attack                            538
# C&C-FileDownload                   46
# C&C-Torii                          30
# FileDownload                       13
# C&C-HeartBeat-FileDownload          8
# Okiru-Attack                        3
# C&C-Mirai                           1
# Name: label, dtype: int64

# %%
df_c.to_csv('iot23_combined_new.csv')
